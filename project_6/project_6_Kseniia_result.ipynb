# %% [markdown]
# # Описание проекта
#
# Интернет-магазин «В один клик» продаёт разные товары: для детей, для дома, мелкую бытовую технику, косметику и даже продукты. Отчёт магазина за прошлый период показал, что активность покупателей начала снижаться. Привлекать новых клиентов уже не так эффективно: о магазине и так знает большая часть целевой аудитории. Возможный выход — удерживать активность постоянных клиентов. Сделать это можно с помощью персонализированных предложений.
#
# «В один клик» — современная компания, поэтому её руководство не хочет принимать решения просто так — только на основе анализа данных и бизнес-моделирования. У компании есть небольшой отдел цифровых технологий, и вам предстоит побыть в роли стажёра в этом отделе.
#
# Итак, вашему отделу поручили разработать решение, которое позволит персонализировать предложения постоянным клиентам, чтобы увеличить их покупательскую активность.

# %% [markdown]
#  **Как решать задачу**
#
# Нужно промаркировать уровень финансовой активности постоянных покупателей. В компании принято выделять два уровня активности: «снизилась», если клиент стал покупать меньше товаров, и «прежний уровень».
#
# Нужно собрать данные по клиентам по следующим группам:
# - Признаки, которые описывают коммуникацию сотрудников компании с клиентом.
# - Признаки, которые описывают продуктовое поведение покупателя. Например, какие товары покупает и как часто.
# - Признаки, которые описывают покупательское поведение клиента. Например, сколько тратил в магазине.
# - Признаки, которые описывают поведение покупателя на сайте. Например, как много страниц просматривает и сколько времени проводит на сайте.
#
# Представим группы признаков (вместе с целевым) в виде диаграммы — такую визуализацию ещё называют диаграммой Исикавы.
# На диаграмме входные признаки объединены в четыре группы:
# - коммуникация с клиентом, продуктовое поведение, поведение на сайте и финансовое поведение.
# - Нужно построить модель, которая предскажет вероятность снижения покупательской активности клиента в следующие три месяца.
# - В исследование нужно включить дополнительные данные финансового департамента о прибыльности клиента: какой доход каждый покупатель приносил компании за последние три месяца.
# ![image.png](attachment:image.png)
#
# Используя данные модели и данные о прибыльности клиентов, нужно выделить сегменты покупателей и разработать для них персонализированные предложения.
#
# Руководство одобрило описание решения, и вам, как специалисту по DS, нужно его реализовать.

# %% [markdown]
# ## Описание данных
#
# **market_file.csv - Таблица, которая содержит данные о поведении покупателя на сайте, о коммуникациях с покупателем и его продуктовом поведении.**
#
# - id — номер покупателя в корпоративной базе данных.
# - Покупательская активность — рассчитанный класс покупательской активности (целевой признак): «снизилась» или «прежний уровень».
# - Тип сервиса — уровень сервиса, например «премиум» и «стандарт».
# - Разрешить сообщать — информация о том, можно ли присылать покупателю дополнительные предложения о товаре. Согласие на это даёт покупатель.
# - Маркет_актив_6_мес — среднемесячное значение маркетинговых коммуникаций компании, которое приходилось на покупателя за последние 6 месяцев. Это значение показывает, какое число рассылок, звонков, показов рекламы и прочего приходилось на клиента.
# - Маркет_актив_тек_мес — количество маркетинговых коммуникаций в текущем месяце.
# - Длительность — значение, которое показывает, сколько дней прошло с момента регистрации покупателя на сайте.
# - Акционные_покупки — среднемесячная доля покупок по акции от общего числа покупок за последние 6 месяцев.
# - Популярная_категория — самая популярная категория товаров у покупателя за последние 6 месяцев.
# - Средний_просмотр_категорий_за_визит — показывает, сколько в среднем категорий покупатель просмотрел за визит в течение последнего месяца.
# - Неоплаченные_продукты_штук_квартал — общее число неоплаченных товаров в корзине за последние 3 месяца.
# - Ошибка_сервиса — число сбоев, которые коснулись покупателя во время посещения сайта.
# - Страниц_за_визит — среднее количество страниц, которые просмотрел покупатель за один визит на сайт за последние 3 месяца.
#
# **market_money.csv - Таблица с данными о выручке, которую получает магазин с покупателя, то есть сколько покупатель всего потратил за период взаимодействия с сайтом.**
#
# - id — номер покупателя в корпоративной базе данных.
# - Период — название периода, во время которого зафиксирована выручка. Например, 'текущий_месяц' или 'предыдущий_месяц'.
# - Выручка — сумма выручки за период.
#
# **market_time.csv - Таблица с данными о времени (в минутах), которое покупатель провёл на сайте в течение периода.**
#
# - id — номер покупателя в корпоративной базе данных.
# - Период — название периода, во время которого зафиксировано общее время.
# - минут — значение времени, проведённого на сайте, в минутах.
#
# **money.csv - Таблица с данными о среднемесячной прибыли покупателя за последние 3 месяца: какую прибыль получает магазин от продаж каждому покупателю.**
#
# - id — номер покупателя в корпоративной базе данных.
# - Прибыль — значение прибыли.
#
# **Инструкция по выполнению проекта**
#
# Решать задачу вам нужно в два этапа:
# - Разработайте модель, которая предскажет вероятность снижения покупательской активности.
# - Выделите сегмент покупателей, проанализируйте его и предложите, как увеличить его покупательскую активность. Используйте данные моделирования, данные о прибыли покупателей и исходные данные (если понадобятся). По желанию вы можете проанализировать больше одного сегмента.
#
# Ниже несколько примеров сегментов, но вы также можете выделить свой:
#
# - Группа клиентов с максимальной долей покупок по акции и высокой вероятностью снижения покупательской активности.
# - Группа клиентов, которые покупают только технику, то есть товары с длинным жизненным циклом.
# - Группа клиентов, которые покупают товары из категории «Товары для себя» (новая категория, которую можно выделить на основе текущих) или «Товары для детей».
# - Группа клиентов с высокой вероятностью снижения покупательской активности и наиболее высокой прибыльностью.

# %%
# !pip install phik 
# !pip install shap
# !pip install --upgrade scikit-learn
# !pip install --upgrade shap
# !pip install --upgrade numba
# !pip install seaborn==0.13.2

# %%
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.inspection import permutation_importance
import matplotlib as mpl

from tqdm.notebook import tqdm
from tqdm import tqdm
import seaborn as sns
import seaborn.objects as so 

import numpy as np
from math import *
#pd.set_option('max_columns', None)# чтобы выводить все столбцы
import plotly.express as px
import scipy.stats as st

from scipy.stats import mode

import phik
from phik import phik_matrix
from phik.report import plot_correlation_matrix

from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer

import numpy as np
from sklearn.model_selection import train_test_split

# загружаем класс pipeline
from sklearn.pipeline import Pipeline

# загружаем классы для подготовки данных
from sklearn.preprocessing import OneHotEncoder, OrdinalEncoder, StandardScaler, MinMaxScaler, RobustScaler, LabelEncoder
from sklearn.compose import ColumnTransformer

# загружаем класс для работы с пропусками
from sklearn.impute import SimpleImputer

# загружаем функцию для работы с метриками
from sklearn.metrics import roc_auc_score

# импортируем класс RandomizedSearchCV
from sklearn.model_selection import RandomizedSearchCV

# загружаем нужные модели
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC

import shap

from warnings import simplefilter
simplefilter(action='ignore', category=FutureWarning)
import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)

# %% [markdown]
# ###  Загрузка данных

# %%
try:
    market_file = pd.read_csv('/datasets/market_file.csv')
    market_file.name = 'market_file'
    market_money = pd.read_csv('/datasets/market_money.csv')
    market_money.name = 'market_money'
    market_time = pd.read_csv('/datasets/market_time.csv')
    market_time.name = 'market_time'
    money = pd.read_csv('/datasets/money.csv',sep = ';',decimal = ',')
    money.name = 'money'
except:
    market_file = pd.read_csv('market_file.csv')
    market_file.name = 'market_file'
    market_money = pd.read_csv('market_money.csv')
    market_money.name = 'market_money'
    market_time = pd.read_csv('market_time.csv')
    market_time.name = 'market_time'
    money = pd.read_csv('money.csv',sep = ';',decimal = ',')
    money.name = 'money'

# %%
all_data_list = [market_file,market_money,market_time,money]

# %%
for i in all_data_list:
    display(i.name)
    display(i.head())
# Out:
# 'market_file'
#        id Покупательская активность Тип сервиса Разрешить сообщать  \
# 0  215348                 Снизилась     премиум                 да
# 1  215349                 Снизилась     премиум                 да
# 2  215350                 Снизилась   стандартт                нет
# 3  215351                 Снизилась   стандартт                 да
# 4  215352                 Снизилась   стандартт                нет
#
#    Маркет_актив_6_мес  Маркет_актив_тек_мес  Длительность  Акционные_покупки  \
# 0                 3.4                     5           121               0.00
# 1                 4.4                     4           819               0.75
# 2                 4.9                     3           539               0.14
# 3                 3.2                     5           896               0.99
# 4                 5.1                     3          1064               0.94
#
#   Популярная_категория  Средний_просмотр_категорий_за_визит  \
# ...

# %% [markdown]
# Мы исправили разделитель значений в таблице money

# %%
for i in all_data_list:
    print(i.name)
    print(' ')
    i.info()
    print(' ')
# Out:
# market_file
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1300 entries, 0 to 1299
# Data columns (total 13 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   id                                   1300 non-null   int64
#  1   Покупательская активность            1300 non-null   object
#  2   Тип сервиса                          1300 non-null   object
#  3   Разрешить сообщать                   1300 non-null   object
#  4   Маркет_актив_6_мес                   1300 non-null   float64
#  5   Маркет_актив_тек_мес                 1300 non-null   int64
#  6   Длительность                         1300 non-null   int64
#  7   Акционные_покупки                    1300 non-null   float64
#  8   Популярная_категория                 1300 non-null   object
#  9   Средний_просмотр_категорий_за_визит  1300 non-null   int64
#  10  Неоплаченные_продукты_штук_квартал   1300 non-null   int64
# ...

# %% [markdown]
# ### Предобработка данных

# %% [markdown]
# #### Замените названия столбцов (приведите к нижнему регистру)

# %%
def to_lower(all_data_list):
    for i in all_data_list:
        i.columns = i.columns.str.lower().str.replace(' ', '_')
to_lower(all_data_list)

# %% [markdown]
# Привели данные к змеиному реистру

# %% [markdown]
# #### Обработайте пропуски при необходимости

# %%
for i in all_data_list:
    print(' ')
    print(i.name)
    print(' ')
    print(i.isna().sum())
# Out:
#
# market_file
#
# id                                     0
# покупательская_активность              0
# тип_сервиса                            0
# разрешить_сообщать                     0
# маркет_актив_6_мес                     0
# маркет_актив_тек_мес                   0
# длительность                           0
# акционные_покупки                      0
# популярная_категория                   0
# средний_просмотр_категорий_за_визит    0
# неоплаченные_продукты_штук_квартал     0
# ошибка_сервиса                         0
# страниц_за_визит                       0
# dtype: int64
#
# market_money
#
# id         0
# период     0
# выручка    0
# dtype: int64
#
# market_time
#
# id        0
# период    0
# минут     0
# dtype: int64
#
# money
#
# id         0
# прибыль    0
# dtype: int64

# %% [markdown]
# Пропусков не было обнаружено

# %% [markdown]
# #### Дубликаты

# %% [markdown]
# Посмотрим на явные дубликаты

# %%
for i in all_data_list:
    print(' ')
    print(i.name)
    print(' ')
    print(i.duplicated().sum())
# Out:
#
# market_file
#
# 0
#
# market_money
#
# 0
#
# market_time
#
# 0
#
# money
#
# 0

# %% [markdown]
# **Теперь проверим на неявные дубликаты**

# %%
for i in all_data_list:
    print(' ')
    print(i.name)
    print(' ')
    for column in i.select_dtypes(include='object').columns:
        print(column)
        print(i[column].unique())
# Out:
#
# market_file
#
# покупательская_активность
# ['Снизилась' 'Прежний уровень']
# тип_сервиса
# ['премиум' 'стандартт' 'стандарт']
# разрешить_сообщать
# ['да' 'нет']
# популярная_категория
# ['Товары для детей' 'Домашний текстиль' 'Косметика и аксесуары'
#  'Техника для красоты и здоровья' 'Кухонная посуда'
#  'Мелкая бытовая техника и электроника']
#
# market_money
#
# период
# ['препредыдущий_месяц' 'текущий_месяц' 'предыдущий_месяц']
#
# market_time
#
# период
# ['текущий_месяц' 'предыдцщий_месяц']
#
# money

# %% [markdown]
# Видим ошибку в таблице - market_file `'стандартт' 'стандарт'`, market_money  `'препредыдущий_месяц' 'предпредыдущий_месяц'`
# Еще ошибка в написании в таблице market_time `предыдцщий_месяц`

# %%
market_file['тип_сервиса'] = market_file['тип_сервиса'].replace('стандартт','стандарт')
print(market_file['тип_сервиса'].unique())
market_money['период'] = market_money['период'].replace('препредыдущий_месяц','предпредыдущий_месяц')
print(market_money['период'].unique())
market_time['период'] = market_time['период'].replace('предыдцщий_месяц','предыдущий_месяц')
print(market_time['период'].unique())
# Out:
# ['премиум' 'стандарт']
# ['предпредыдущий_месяц' 'текущий_месяц' 'предыдущий_месяц']
# ['текущий_месяц' 'предыдущий_месяц']

# %% [markdown]
# Мы избавились от неявных дубликатов

# %% [markdown]
# **Вывод:**
# - Привели данные к змеиному реистру
# - Пропусков не было обнаружено
# - Явных дубликатов не обнаружено
# - Неявные дубликаты: Видим ошибку в таблице - market_file 'стандартт' 'стандарт. Еще ошибка в написании в таблице market_time предыдцщий_месяц

# %% [markdown]
# ### Исследовательский анализ данных

# %% [markdown]
# Проведите исследовательский анализ данных из каждой таблицы.
# - Отберите клиентов с покупательской активностью не менее трёх месяцев и которые что-либо покупали в этот период
# - Оформите выводы по результатам шага.

# %% [markdown]
# money.csv
# Таблица с данными о среднемесячной прибыли покупателя за последние 3 месяца: какую прибыль получает магазин от продаж каждому покупателю.

# %% [markdown]
# **market_file**

# %%
market_file.set_index('id', inplace=True)
market_file.head()
# Out:
#        покупательская_активность тип_сервиса разрешить_сообщать  \
# id
# 215348                 Снизилась     премиум                 да
# 215349                 Снизилась     премиум                 да
# 215350                 Снизилась    стандарт                нет
# 215351                 Снизилась    стандарт                 да
# 215352                 Снизилась    стандарт                нет
#
#         маркет_актив_6_мес  маркет_актив_тек_мес  длительность  \
# id
# 215348                 3.4                     5           121
# 215349                 4.4                     4           819
# 215350                 4.9                     3           539
# 215351                 3.2                     5           896
# 215352                 5.1                     3          1064
#
#         акционные_покупки популярная_категория  \
# id
# 215348               0.00     Товары для детей
# 215349               0.75     Товары для детей
# ...

# %%
fig = plt.figure(figsize=(25, 15))
for i, column in enumerate(market_file.columns):
    ax = fig.add_subplot(4, 4, i + 1)
    ax_hist = ax.twinx()  
    if market_file[column].dtype == 'object':
        market_file[column].value_counts().plot(kind='barh')
        plt.title(column)
        ax.set_xticks([])  # Убираем метки на оси x
        ax.set_yticks([])  # Убираем метки на оси y
    else:
        market_file[column].hist(bins = 50)
        plt.title(column)
        ax.set_xticks([])  # Убираем метки на оси x
        ax.set_yticks([])  # Убираем метки на оси y
plt.tight_layout()  # Автоматически подгоняем размер подграфиков для лучшей компоновки
plt.show()  # Отображаем графики

# %% [markdown]
# Видим, что выбросов не видно,разве что подозрительные данные в аукционных покупках Построим ящик с усами для всез столбцов

# %%
fig = plt.figure(figsize=(25, 15))
# Счетчик для индекса подграфика
subplot_index = 1

for i, column in enumerate(market_file.columns):
    if market_file[column].dtype != 'object':
        ax = fig.add_subplot(3, 4, subplot_index)
        ax_hist = ax.twinx() 
        # Отображаем боксплот только для этого столбца
        market_file.boxplot(column, ax=ax) 
        plt.title(column)
        ax.set_xticks([])  # Убираем метки на оси x
        ax.set_yticks([])  # Убираем метки на оси y

        # Увеличиваем счетчик для следующего подграфика
        subplot_index += 1

plt.tight_layout()  # Автоматически подгоняем размер подграфиков для лучшей компоновки
plt.show()  # Отображаем графики

# %% [markdown]
# Выбросов не видно, посмотрим через describe

# %%
market_file.describe().T
# Out:
#                                       count        mean         std    min  \
# маркет_актив_6_мес                   1300.0    4.253769    1.014814    0.9
# маркет_актив_тек_мес                 1300.0    4.011538    0.696868    3.0
# длительность                         1300.0  601.898462  249.856289  110.0
# акционные_покупки                    1300.0    0.319808    0.249843    0.0
# средний_просмотр_категорий_за_визит  1300.0    3.270000    1.355350    1.0
# неоплаченные_продукты_штук_квартал   1300.0    2.840000    1.971451    0.0
# ошибка_сервиса                       1300.0    4.185385    1.955298    0.0
# страниц_за_визит                     1300.0    8.176923    3.978126    1.0
#
#                                         25%     50%    75%      max
# маркет_актив_6_мес                     3.70    4.20    4.9     6.60
# маркет_актив_тек_мес                   4.00    4.00    4.0     5.00
# длительность                         405.50  606.00  806.0  1079.00
# ...

# %% [markdown]
# *Никаких аномальных значений в таблице market_file не было обнаружено*

# %% [markdown]
# **market_money**

# %%
market_money2 = market_money.drop('id', axis = 1)

# %%
fig = plt.figure(figsize=(25, 15))
for i, column in enumerate(market_money2.columns):
    ax = fig.add_subplot(4, 4, i + 1)
    ax_hist = ax.twinx()  
    if market_money2[column].dtype == 'object':
        market_money2[column].value_counts().plot(kind='barh')
        plt.title(column)
    else:
        market_money2[column].hist(bins = 50, ec='black', alpha=0.5)
        plt.title(column)

plt.tight_layout()  # Автоматически подгоняем размер подграфиков для лучшей компоновки
plt.show()  # Отображаем графики

# %%
for column in market_money2.columns:
    if market_money2[column].dtype != 'object' :
        market_money2.boxplot(column)
        plt.title(column)
        plt.show()

# %%
market_money2.describe()
# Out:
#              выручка
# count    3900.000000
# mean     5025.696051
# std      1777.704104
# min         0.000000
# 25%      4590.150000
# 50%      4957.500000
# 75%      5363.000000
# max    106862.200000

# %% [markdown]
# Видим одно аномальное значение - посмотрим по подробнее

# %%
market_money[market_money['выручка']>= 100000]
# Out:
#         id         период   выручка
# 98  215380  текущий_месяц  106862.2

# %%
market_file[market_file.index == 215380]
# Out:
#        покупательская_активность тип_сервиса разрешить_сообщать  \
# id
# 215380                 Снизилась     премиум                нет
#
#         маркет_актив_6_мес  маркет_актив_тек_мес  длительность  \
# id
# 215380                 1.7                     4           637
#
#         акционные_покупки            популярная_категория  \
# id
# 215380               0.94  Техника для красоты и здоровья
#
#         средний_просмотр_категорий_за_визит  \
# id
# 215380                                    3
#
#         неоплаченные_продукты_штук_квартал  ошибка_сервиса  страниц_за_визит
# id
# 215380                                   2               4                 7

# %% [markdown]
# Больше похоже на выброс, покупательская активность снизилась, возникали ошибки при входе на сайт, покупка исключительно по акции. Удалим этот выброс

# %%
market_money = market_money.query('выручка <= 100000')

# %%
market_money.describe()
# Out:
#                   id     выручка
# count    3899.000000  3899.00000
# mean   215997.658374  4999.57743
# std       375.243472   706.99988
# min    215348.000000     0.00000
# 25%    215673.000000  4590.10000
# 50%    215998.000000  4957.00000
# 75%    216322.500000  5363.00000
# max    216647.000000  7799.40000

# %% [markdown]
# **market_time**

# %%
market_time2 = market_time.drop('id', axis = 1)

# %%
fig = plt.figure(figsize=(25, 15))
for i, column in enumerate(market_time2.columns):
    ax = fig.add_subplot(4, 4, i + 1)
    ax_hist = ax.twinx()  
    if market_time2[column].dtype == 'object':
        market_time2[column].value_counts().plot(kind='barh')
        plt.title(column)
    else:
        market_time2[column].hist(bins = 50, ec='black', alpha=0.5)
        ax.boxplot(market_time2[column], vert=False, patch_artist=True, boxprops={'facecolor': 'lightblue'})
        plt.title(column)

plt.tight_layout()  # Автоматически подгоняем размер подграфиков для лучшей компоновки
plt.show()  # Отображаем графики

# %%
market_time2.describe()
# Out:
#              минут
# count  2600.000000
# mean     13.336154
# std       4.080198
# min       4.000000
# 25%      10.000000
# 50%      13.000000
# 75%      16.000000
# max      23.000000

# %% [markdown]
# Выброссов и аномальных значений - нет

# %% [markdown]
# **money**

# %%
money2 = money.drop('id', axis = 1)

# %%
fig = plt.figure(figsize=(25, 15))
for i, column in enumerate(money2.columns):
    ax = fig.add_subplot(4, 4, i + 1)
    ax_hist = ax.twinx()  
    money2[column].hist(bins = 50, ec='black', alpha=0.5)
    ax.boxplot(money2[column], vert=False, patch_artist=True, boxprops={'facecolor': 'lightblue'})
    plt.title(column)

plt.tight_layout()  # Автоматически подгоняем размер подграфиков для лучшей компоновки
plt.show()  # Отображаем графики

# %%
money2.describe()
# Out:
#            прибыль
# count  1300.000000
# mean      3.996631
# std       1.013722
# min       0.860000
# 25%       3.300000
# 50%       4.045000
# 75%       4.670000
# max       7.430000

# %% [markdown]
# Выбросов и аномальных значний нет

# %% [markdown]
# **Вывод:**
# - в таблице money - выбросов и аномальных значний нет
# - в таблице market_time - выбросов и аномальных значний нет
# - в таблице market_money = удалили выброс 'выручка >= 100000'
# - в таблице market_file - выбросов и аномальных значний нет

# %%
active_clients = market_file.merge(market_money, on='id', how='inner')

def filter_rows(group):
    mask = (((group['период'] == 'предпредыдущий_месяц') & (group['выручка'] == 0)) | 
            ((group['период'] == 'текущий_месяц') & (group['выручка'] == 0)) | 
            ((group['период'] == 'предыдущий_месяц') & (group['выручка'] == 0)))
    return group.loc[~mask]

# Apply the function for each unique 'id'
active_buying_clients = active_clients.groupby('id').apply(filter_rows).reset_index(drop=True)
active_buying_clients.head()
# Out:
#        id покупательская_активность тип_сервиса разрешить_сообщать  \
# 0  215348                 Снизилась     премиум                 да
# 1  215349                 Снизилась     премиум                 да
# 2  215349                 Снизилась     премиум                 да
# 3  215349                 Снизилась     премиум                 да
# 4  215350                 Снизилась    стандарт                нет
#
#    маркет_актив_6_мес  маркет_актив_тек_мес  длительность  акционные_покупки  \
# 0                 3.4                     5           121               0.00
# 1                 4.4                     4           819               0.75
# 2                 4.4                     4           819               0.75
# 3                 4.4                     4           819               0.75
# 4                 4.9                     3           539               0.14
#
#   популярная_категория  средний_просмотр_категорий_за_визит  \
# ...

# %%
plt.figure(figsize=(20, 5))
plt.title('Распределение выручки', fontsize=20)
plt.plot(active_buying_clients['выручка'],'-*',label='выручка');
plt.ylabel('Выручка')
plt.legend();
active_buying_clients['выручка'].describe()
# Out:
# count    3893.000000
# mean     5007.282918
# std       679.724898
# min      2758.700000
# 25%      4592.000000
# 50%      4959.000000
# 75%      5363.000000
# max      7799.400000
# Name: выручка, dtype: float64

# %%
active_buying_clients['покупательская_активность'].value_counts()
# Out:
# покупательская_активность
# Прежний уровень    2406
# Снизилась          1487
# Name: count, dtype: int64

# %%
active_buying_clients['тип_сервиса'].value_counts()
# Out:
# тип_сервиса
# стандарт    2768
# премиум     1125
# Name: count, dtype: int64

# %%
active_buying_clients['популярная_категория'].value_counts()
# Out:
# популярная_категория
# Товары для детей                        988
# Домашний текстиль                       751
# Косметика и аксесуары                   669
# Техника для красоты и здоровья          549
# Мелкая бытовая техника и электроника    522
# Кухонная посуда                         414
# Name: count, dtype: int64

# %%
active_buying_clients['акционные_покупки'].value_counts()
# Out:
# акционные_покупки
# 0.24    279
# 0.30    255
# 0.28    249
# 0.17    237
# 0.25    216
# 0.14    207
# 0.21    192
# 0.13    192
# 0.16    186
# 0.23    180
# 0.15    147
# 0.94    128
# 0.22    102
# 0.11     93
# 0.40     93
# 0.99     90
# 0.27     81
# 0.35     78
# 0.95     72
# 0.26     72
# 0.18     69
# 0.20     63
# 0.12     60
# 0.32     60
# 0.29     57
# 0.93     57
# 0.39     54
# 0.98     51
# 0.89     48
# 0.33     45
# 0.19     33
# 0.36     33
# 0.90     33
# 0.31     30
# 0.91     15
# 0.34     15
# 0.44      6
# 0.60      3
# 0.75      3
# 0.74      3
# 0.47      3
# 0.00      3
# Name: count, dtype: int64

# %% [markdown]
# Вывод о таблице с покупательской активностью не менее трёх месяцев, и которые что-либо покупали в этот период:
# - покупательская активность в боьшистве осталась прежней
# - в основном покупатели придерживаются типа сервиса - стандарт
# - самая популярная категория - Товары для детей
# - чаще всего люди покупают без акций

# %% [markdown]
# **Вывод**
# - в таблице money - выбросов и аномальных значний нет
# - в таблице market_time - выбросов и аномальных значний нет
# - в таблице market_money = удалили выброс 'выручка >= 100000'
# - в таблице market_file - выбросов и аномальных значний нет
#
# - покупательская активность в боьшистве осталась прежней
# - в основном покупатели придерживаются типа сервиса - стандарт
# - самая популярная категория - Товары для детей
# - чаще всего люди покупают без акций

# %% [markdown]
# ### Объединение таблиц

# %% [markdown]
# 4.1 Объедините таблицы market_file.csv, market_money.csv, market_time.csv. Данные о прибыли из файла money.csv при моделировании вам не понадобятся.
#
# 4.2 Учитывайте, что данные о выручке и времени на сайте находятся в одном столбце для всех периодов. В итоговой таблице сделайте отдельный столбец для каждого периода.

# %%
len(market_file),len(market_money),len(market_time)
# Out:
# (1300, 3899, 2600)

# %%
# Используем pivot_table для преобразования таблиц df_money и df_time
df_money_pivot = market_money.pivot_table(index='id', columns='период', values='выручка')
df_time_pivot = market_time.pivot_table(index='id', columns='период', values='минут')

# Объединяем преобразованные таблицы
df_final = pd.merge(df_money_pivot, df_time_pivot, on='id')

df_final.head()
# Out:
# период  предпредыдущий_месяц  предыдущий_месяц_x  текущий_месяц_x  \
# id
# 215348                   0.0                 0.0           3293.1
# 215349                4472.0              5216.0           4971.6
# 215350                4826.0              5457.5           5058.4
# 215351                4793.0              6158.0           6610.4
# 215352                4594.0              5807.5           5872.5
#
# период  предыдущий_месяц_y  текущий_месяц_y
# id
# 215348                13.0             14.0
# 215349                12.0             10.0
# 215350                 8.0             13.0
# 215351                11.0             13.0
# 215352                 8.0             11.0

# %%
# Объединение таблиц
merged_data = pd.merge(market_file, df_final, left_index=True, right_index=True)

def filter_rows(group):
    mask = ((group['предпредыдущий_месяц'] == 0) | 
            (group['предыдущий_месяц_x'] == 0) | 
            (group['текущий_месяц_x'] == 0))
    return group.loc[~mask]

merged_data = merged_data.loc[~((merged_data['предпредыдущий_месяц'] == 0) | 
                              (merged_data['предыдущий_месяц_x'] == 0) | (merged_data['текущий_месяц_x'] == 0))]
merged_data= merged_data.query('текущий_месяц_x < 100000')
merged_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1296 entries, 215349 to 216647
# Data columns (total 17 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   покупательская_активность            1296 non-null   object
#  1   тип_сервиса                          1296 non-null   object
#  2   разрешить_сообщать                   1296 non-null   object
#  3   маркет_актив_6_мес                   1296 non-null   float64
#  4   маркет_актив_тек_мес                 1296 non-null   int64
#  5   длительность                         1296 non-null   int64
#  6   акционные_покупки                    1296 non-null   float64
#  7   популярная_категория                 1296 non-null   object
#  8   средний_просмотр_категорий_за_визит  1296 non-null   int64
#  9   неоплаченные_продукты_штук_квартал   1296 non-null   int64
#  10  ошибка_сервиса                       1296 non-null   int64
# ...

# %%
merged_data.shape
# Out:
# (1296, 17)

# %% [markdown]
# ### Корреляционный анализ

# %% [markdown]
# Проведите корреляционный анализ признаков в количественной шкале в итоговой таблице для моделирования. Сделайте выводы о мультиколлинеарности и при необходимости устраните её.

# %%
interval_cols = merged_data.select_dtypes(include = ['int','float'])

phik_overview = merged_data.phik_matrix(interval_cols=interval_cols)

plot_correlation_matrix(
    phik_overview.values,
    x_labels=phik_overview.columns,
    y_labels=phik_overview.index,
    title=r"correlation $\phi_K$",
    vmin=0, vmax=1, color_map='Greens',
    fontsize_factor=1.5,
    figsize=(15, 12)
)

# %%
high_phik_correlation = (phik_overview > 0.8) & (phik_overview < 1.0)

# Display the pairs of features with high Phik correlation values
high_phik_correlation_pairs = np.argwhere(high_phik_correlation.values)
for pair in high_phik_correlation_pairs:
    feature1 = merged_data.columns[pair[0]]
    feature2 = merged_data.columns[pair[1]]
    print(f"Признак '{feature1}' и '{feature2}' имеют высокую корреляцию ")
# Out:
# Признак 'предыдущий_месяц_x' и 'текущий_месяц_x' имеют высокую корреляцию
# Признак 'текущий_месяц_x' и 'предыдущий_месяц_x' имеют высокую корреляцию

# %% [markdown]
#  значения текущий_месяц_x и предыдущий_месяц_x они имеют самую высокую корреляцию

# %%
merged_data = merged_data.drop('предыдущий_месяц_x', axis = 1)

# %%
interval_cols = merged_data.select_dtypes(include = ['int','float'])

phik_overview = merged_data.phik_matrix(interval_cols=interval_cols)

plot_correlation_matrix(
    phik_overview.values,
    x_labels=phik_overview.columns,
    y_labels=phik_overview.index,
    title=r"correlation $\phi_K$",
    vmin=0, vmax=1, color_map='Greens',
    fontsize_factor=1.5,
    figsize=(15, 12)
)

# %% [markdown]
# Мы нашли мультиколлинеарность признаков текущий_месяц_x,предыдущий_месяц_x со многими столбцами и удалили один из этих признаков из датафрейма

# %% [markdown]
# ### Использование пайплайнов

# %% [markdown]
# Закодируем покупательская_активность пусть Снизилась - 1, Прежний уровень - 0

# %%
merged_data['покупательская_активность'] = merged_data['покупательская_активность'].replace('Снизилась',1)
merged_data['покупательская_активность'] = merged_data['покупательская_активность'].replace('Прежний уровень',0)
merged_data['покупательская_активность'] = merged_data['покупательская_активность'].astype(int)
merged_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1296 entries, 215349 to 216647
# Data columns (total 16 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   покупательская_активность            1296 non-null   int32
#  1   тип_сервиса                          1296 non-null   object
#  2   разрешить_сообщать                   1296 non-null   object
#  3   маркет_актив_6_мес                   1296 non-null   float64
#  4   маркет_актив_тек_мес                 1296 non-null   int64
#  5   длительность                         1296 non-null   int64
#  6   акционные_покупки                    1296 non-null   float64
#  7   популярная_категория                 1296 non-null   object
#  8   средний_просмотр_категорий_за_визит  1296 non-null   int64
#  9   неоплаченные_продукты_штук_квартал   1296 non-null   int64
#  10  ошибка_сервиса                       1296 non-null   int64
# ...

# %%
RANDOM_STATE = 42
TEST_SIZE = 0.25

y = merged_data['покупательская_активность']
X = merged_data.drop('покупательская_активность', axis=1)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=TEST_SIZE, random_state=RANDOM_STATE, stratify=y)

# Создаём списки с названиями признаков
ohe_columns = [col for col in merged_data.select_dtypes(include = 'object').columns.tolist() if col != 'тип_сервиса']
ord_columns = ['тип_сервиса']
num_columns = [col for col in merged_data.select_dtypes(include = ['int','float']).columns.tolist() 
               if col != 'покупательская_активность']

# Создаём пайплайн для подготовки признаков из списка ohe_columns: заполнение пропусков и OHE-кодирование

ohe_pipe = Pipeline(
    [('simpleImputer_ohe', SimpleImputer(missing_values=np.nan, strategy='most_frequent')),
      ('ohe', OneHotEncoder(drop='first', handle_unknown='ignore',sparse_output = False)),
    ])
ord_pipe = Pipeline(
    [('simpleImputer_before_ord', SimpleImputer(missing_values=np.nan, strategy='most_frequent')),
     ('ord', OrdinalEncoder(categories = [['премиум', 'стандарт']], 
                            handle_unknown='use_encoded_value',unknown_value = np.nan)),
     ('simpleImputer_after_ord', SimpleImputer(missing_values=np.nan, strategy='most_frequent'))
    ])


# Создаём общий пайплайн для подготовки данных
data_preprocessor = ColumnTransformer(
    [('ohe', ohe_pipe, ohe_columns),
     ('ord', ord_pipe, ord_columns),
     ('num', MinMaxScaler(), num_columns)
    ], remainder='passthrough'
)

# Создаём итоговый пайплайн: подготовка данных и модель
pipe_final = Pipeline([
    ('preprocessor', data_preprocessor),
    ('models', KNeighborsClassifier())
])

param_grid = [
    # словарь для модели DecisionTreeClassifier()
    {
        'models': [DecisionTreeClassifier(random_state=RANDOM_STATE)],
        'models__max_depth': range(2,5),
        'models__max_features': range(2,5),
        'preprocessor__num': [StandardScaler(), MinMaxScaler(),RobustScaler(), 'passthrough']  
    },
    
    # словарь для модели KNeighborsClassifier() 
    {
        'models': [KNeighborsClassifier()],
        'models__n_neighbors': range(2,5),
        'models__p': [1, 2],
        'preprocessor__num': [StandardScaler(), MinMaxScaler(),RobustScaler(), 'passthrough']   
    },

    # словарь для модели LogisticRegression()
    {
        'models': [LogisticRegression(
            random_state=RANDOM_STATE, 
            solver='liblinear', 
            penalty='l1'
        )],
        'models__C': range(1,5),
        'preprocessor__num': [StandardScaler(), MinMaxScaler(),RobustScaler(), 'passthrough']  
    },
    
    # Словарь для модели SVC
    {
        'models': [SVC(random_state=RANDOM_STATE, probability=True)],
        'models__C': [0.1, 1, 10],
        'models__kernel': ['linear', 'rbf'],
        'preprocessor__num': [StandardScaler(), MinMaxScaler(),RobustScaler(), 'passthrough']
    }
]

# %%
merged_data['покупательская_активность'].value_counts()
# Out:
# покупательская_активность
# 0    802
# 1    494
# Name: count, dtype: int64

# %% [markdown]
# - Видим, что значений 0(Прежний уровень) в 2 раза больше, чем 1(Снизилась)
# - Нужно построить модель, которая предскажет вероятность снижения покупательской активности клиента в следующие три месяца.
#
# **Для оценки производительности модели в нашем случае, рекомендуется использовать AUC-ROC. Эта метрика измеряет способность модели отличать два класса и является подходящей для проблем с несбалансированными классами, как в нашем случае. Она предоставляет информацию о том, насколько хорошо модель может отличать снижение покупательской активности от её сохранения**

# %%
# Выполняем перекрёстную проверку с рандомизированным поиском
randomized_search = RandomizedSearchCV(
    pipe_final, 
    param_grid, 
    cv=5,
    scoring='roc_auc',
    random_state=RANDOM_STATE,
    n_jobs=-1
)
randomized_search.fit(X_train, y_train)

print('Лучшая модель и её параметры:\n\n', randomized_search.best_estimator_)
print ('Метрика лучшей модели на тренировочной выборке:', randomized_search.best_score_)


y_test_pred = randomized_search.predict_proba(X_test)

print('Площадь ROC-кривой:', roc_auc_score(y_test, y_test_pred[:, 1]))
# Out:
# Лучшая модель и её параметры:
#
#  Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('ohe',
#                                                   Pipeline(steps=[('simpleImputer_ohe',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('ohe',
#                                                                    OneHotEncoder(drop='first',
#                                                                                  handle_unknown='ignore',
#                                                                                  sparse_output=False))]),
#                                                   ['разрешить_сообщать',
#                                                    'популярная_категория']),
#                                                  ('ord',
# ...

# %% [markdown]
# **Лучшая модель - SVC(C=0.1, probability=True, random_state=42)**
#
# **Лучший стандартизатор - StandartScaler()**

# %%
best_model = randomized_search.best_estimator_
#best_model = best_model.named_steps['models'] 
best_model
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('ohe',
#                                                   Pipeline(steps=[('simpleImputer_ohe',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('ohe',
#                                                                    OneHotEncoder(drop='first',
#                                                                                  handle_unknown='ignore',
#                                                                                  sparse_output=False))]),
#                                                   ['разрешить_сообщать',
#                                                    'популярная_категория']),
#                                                  ('ord',
# ...

# %% [markdown]
# ### Анализ важности признаков

# %%
# Извлекаем шаги предобработки и моделирования из лучшего пайплайна
best_pipeline = randomized_search.best_estimator_
preprocessor = best_pipeline.named_steps['preprocessor']
model = best_pipeline.named_steps['models']
preprocessor_col = preprocessor.get_feature_names_out()

# Применяем шаги предобработки к обучающим данным
X_train_preprocessed = preprocessor.transform(X_train)
X_train_preprocessed = pd.DataFrame(X_train_preprocessed,columns = preprocessor_col)

# %%
# Выполняем перестановку признаков
result = permutation_importance(best_model, X_test, y_test, n_repeats=10, random_state=RANDOM_STATE)

# Сортируем по убыванию среднего значения важности
sorted_idx = result.importances_mean.argsort()[::-1]

# Выводим результаты
print("Важность признаков по перестановке:")
for i in sorted_idx:
    col = X_test.columns[i]
    corr = result.importances_mean[i]
    print(f"{col}: {corr:.4f}")
# Out:
# Важность признаков по перестановке:
# страниц_за_визит: 0.0590
# предыдущий_месяц_y: 0.0386
# текущий_месяц_y: 0.0315
# акционные_покупки: 0.0299
# маркет_актив_6_мес: 0.0228
# средний_просмотр_категорий_за_визит: 0.0123
# предпредыдущий_месяц: 0.0080
# неоплаченные_продукты_штук_квартал: 0.0062
# длительность: 0.0012
# популярная_категория: 0.0009
# маркет_актив_тек_мес: 0.0000
# разрешить_сообщать: 0.0000
# тип_сервиса: 0.0000
# текущий_месяц_x: -0.0006
# ошибка_сервиса: -0.0012

# %% [markdown]
# Самые важные признаки при перестановке - страниц_за_визит,предыдущий_месяц_y,текущий_месяц_y,акционные_покупки

# %%
background = shap.sample(X_train_preprocessed, 100) # Используйте 100 случайных образцов из X_train

explainer = shap.KernelExplainer(model.predict_proba, background)  
                                                                       
SHAP_values = explainer.shap_values(background)[..., 1]

shap.summary_plot(SHAP_values, background)
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]

# %% [markdown]
# - Чем больше значения признаков "акционные покупки" и "неоплаченные продукты": тем меньше SHAP‑значения объектов. Если у наблюдения высокое значение этих признаков, то у него высокая вероятность принадлежности к классу 0.
#
# - Чем больше значение признака "текущий месяц","предыдущий месяц","страниц за визит" и "средний просмотр категории": тем выше SHAP-значения. Если у наблюдения высокое значение этого признака, то у него высокая вероятность принадлежности к классу 1.

# %%
sample_index = 0  

shap.waterfall_plot(shap.Explanation(values=SHAP_values[3], 
                                         base_values=explainer.expected_value[1], 
                                         data=X_train_preprocessed.iloc[sample_index], 
                                         feature_names=X_train_preprocessed.columns), show=True)

# %% [markdown]
# - Сильнее всего на его классификацию влияет признак "акционные покупки" и "предыдущий_месяц_y": он «перетягивает» предсказание в сторону класса 1(Снизилась)
# - предсказание в сторону класса 0 влияет признак "ошибка сервиса" и "средний просмотр категорий"

# %% [markdown]
#                                          Выводы о значимости признаков:
#
# 1. **Малозначимые признаки:** разрешить_сообщать, тип_сервиса, предпредыдущий_месяц - эти признаки имеют очень низкое значение важности по перестановке (Permutation Importance). Их влияние на модель минимально, можно рассмотреть возможность их удаления для упрощения модели.
#
#
# 2. **Важные признаки:**
# - *Сильнее всего влияют на целевой признак:* страниц_за_визит, предыдущий_месяц_y, акционные_покупки.
# - *Также важны:* средний_просмотр_категорий_за_визит, неоплаченные_продукты_штук_квартал, маркет_актив_6_мес, текущий_месяц_y.
#
# 3. **Интерпретация SHAP-значений:**
#
# -  акционные_покупки и неоплаченные_продукты_штук_квартал: Чем больше значения этих признаков, тем меньше SHAP-значения. Это означает, что чем больше клиент совершает акционных покупок и имеет неоплаченных продуктов, тем выше вероятность, что целевой признак будет равен 0 (например, “Снизилась”).
# -  предыдущий_месяц_y, страниц_за_визит, средний_просмотр_категорий_за_визит: Чем больше значения этих признаков, тем выше SHAP-значения. Это означает, что чем больше “предыдущий месяц_y”, “страниц_за_визит” и “средний просмотр категорий” у клиента, тем выше вероятность, что целевой признак будет равен 1 (например, “Осталась стабильной”).
#
#
#
#                         **Использование наблюдений при моделировании и принятии решений:**
#
# **Моделирование:**
#
# 1. Упрощение модели: Удалите малозначимые признаки (разрешить_сообщать, тип_сервиса, предпредыдущий_месяц) для повышения скорости обучения и улучшения обобщающей способности модели.
# 2. Выбор признаков: Сосредоточьтесь на самых важных признаках (страниц_за_визит, предыдущий_месяц_y, акционные_покупки) при создании новых признаков или использовании методов селекции признаков.
# 3. Анализ взаимодействий: Изучите взаимодействия между важными признаками, используя SHAP или другие методы анализа, чтобы лучше понять, как они совместно влияют на целевую переменную.
#
# **Принятие бизнес-решений:**
#
# 1. Целевая аудитория: Сосредоточьтесь на клиентах с высокими значениями страниц_за_визит, предыдущий_месяц_y, и средний_просмотр_категорий_за_визит (чтобы повысить вероятность положительного исхода).
# 2. Маркетинговые стратегии: Разработайте стратегии, которые учитывают влияние акционные_покупки и неоплаченные_продукты_штук_квартал (чтобы снизить вероятность отрицательного исхода).
# 3. Сегментация клиентов: Создайте сегменты клиентов на основе ключевых признаков, чтобы разработать индивидуальные предложения.
# 4. Мониторинг изменений: Регулярно анализируйте важность признаков, чтобы отслеживать изменения в поведении клиентов и корректировать бизнес-стратегии.
#
# **Дополнительные рекомендации:**
#
# 1. Ошибки сервиса: Примите во внимание признак ошибка_сервиса, хотя он и не слишком важен. Если он влияет на целевую переменную, то устранение ошибок сервиса должно быть приоритетом.
# 2. Context: Важно помнить, что анализ важности признаков – это только один из инструментов. Всегда учитывайте контекст бизнеса, дополнительные исследования и интуицию специалистов.

# %% [markdown]
# ### Сегментация покупателей

# %% [markdown]
# #### 8.1 Выполните сегментацию покупателей. Используйте результаты моделирования и данные о прибыльности покупателей

# %% [markdown]
# Сегментация покупателей:
# 1) Сегмент : высокоприбыльные с высокой вероятностью снижения активности
#
# Критерии:
# - Высокая прибыльность.
# - Высокие значения акционные_покупки и неоплаченные_продукты_штук_квартал.
# - Низкие значения страниц_за_визит, предыдущий_месяц_y, и средний_просмотр_категорий_за_визит.
# - Отрицательные SHAP-значения для ключевых признаков.
#
# Стратегия: Проведите анализ причин оттока, предложите специальные скидки и программы лояльности, постарайтесь вернуть клиента.
#
# 2) Дополнительно возьмем сегмент: Высокоприбыльные с низкой вероятностью снижения активности

# %% [markdown]
# #### 8.2 Выберите группу покупателей и предложите, как увеличить её покупательскую активность:
#     - Проведите графическое и аналитическое исследование группы покупателей.
#     - Сделайте предложения по работе с сегментом для увеличения покупательской активности.

# %%
money = money.set_index('id')
money.describe()
# Out:
#            прибыль
# count  1300.000000
# mean      3.996631
# std       1.013722
# min       0.860000
# 25%       3.300000
# 50%       4.045000
# 75%       4.670000
# max       7.430000

# %% [markdown]
# Возьмем чуть больше половины значения - 4.3

# %%
# Получите предсказания вашей модели
y_pred = randomized_search.predict_proba(X_test)[:, 1]

# Добавьте предсказания и прибыль в ваш датафрейм
data_for_plot = X_test.copy()
data_for_plot['вероятность_снижения'] = y_pred
data_for_plot['прибыль'] = money['прибыль']
data_for_plot = data_for_plot.query('прибыль > 4.3')

# Определите вашу группу клиентов и все остальные группы
seg_1 = data_for_plot[(data_for_plot['вероятность_снижения'] >= 0.7)]
all_other = data_for_plot[(data_for_plot['вероятность_снижения'] < 0.7)]

# Постройте график
plt.figure(figsize=(12,6))
sns.scatterplot(data=seg_1, x='вероятность_снижения', y='прибыль', label='Исследуемый сегмент', color='blue')
sns.scatterplot(data=all_other, x='вероятность_снижения', y='прибыль', label='Другие сегменты', color='purple')
plt.legend()
plt.axvline(x=0.7, color='green', linestyle='--')
plt.axhline(y=4.3, color='green', linestyle='--')
plt.show()

# %%
data_for_plot.head()
# Out:
#        тип_сервиса разрешить_сообщать  маркет_актив_6_мес  \
# id
# 216161    стандарт                 да                 4.1
# 215934    стандарт                нет                 5.5
# 216493    стандарт                 да                 5.3
# 216312    стандарт                 да                 4.9
# 216318     премиум                 да                 3.9
#
#         маркет_актив_тек_мес  длительность  акционные_покупки  \
# id
# 216161                     4           606               0.15
# 215934                     4           147               0.99
# 216493                     4           129               0.21
# 216312                     5           215               0.15
# 216318                     5          1040               0.30
#
#                         популярная_категория  \
# id
# 216161        Техника для красоты и здоровья
# 215934  Мелкая бытовая техника и электроника
# 216493                     Домашний текстиль
# ...

# %% [markdown]
# Порог 0.7 - клиент, у которого вероятность снижения активности 0.8, будет отнесен к сегменту “высокоприбыльные с высокой вероятностью снижения активности”. А клиент с вероятностью 0.6 будет отнесен к сегменту с низкой вероятностью снижения активности.

# %%
plt.figure(figsize=(10,5))
sns.countplot(x='акционные_покупки', data=seg_1)
plt.title(f' акционные_покупки - высокоприбыльные с высокой вероятностью снижения активности')
plt.show()

plt.figure(figsize=(10,5))
sns.countplot(x='акционные_покупки', data=all_other)
plt.title(f' акционные_покупки - высокоприбыльные с низкой вероятностью снижения активности')
plt.show()

# %%
fig, axes = plt.subplots(1, 2, figsize=(15, 5))  # 1 строка, 2 столбца

# Первая диаграмма
seg_1['маркет_актив_тек_мес'].value_counts().plot(
    kind='pie', autopct='%1.1f%%', ax=axes[0]  # Указываем ось для диаграммы
)
axes[0].set_title(f'маркет_актив_тек_мес (Высокий риск)')

# Вторая диаграмма
all_other['маркет_актив_тек_мес'].value_counts().plot(
    kind='pie', autopct='%1.1f%%', ax=axes[1]
)
axes[1].set_title(f'маркет_актив_тек_мес (Низкий риск)')

# Добавляем заголовок фигуры
fig.suptitle('Распределение маркет_актив_тек_мес')
plt.show()


fig, axes = plt.subplots(1, 2, figsize=(15, 5))  # 1 строка, 2 столбца

# Первая диаграмма
seg_1['тип_сервиса'].value_counts().plot(
    kind='pie', autopct='%1.1f%%', ax=axes[0]  # Указываем ось для диаграммы
)
axes[0].set_title(f'тип_сервиса (Высокий риск)')

# Вторая диаграмма
all_other['тип_сервиса'].value_counts().plot(
    kind='pie', autopct='%1.1f%%', ax=axes[1]
)
axes[1].set_title(f'тип_сервиса (Низкий риск)')

# Добавляем заголовок фигуры
fig.suptitle('Распределение тип_сервиса')

plt.show()

# %%
# Создаем фигуру и оси для диаграмм
fig, axes = plt.subplots(1, 2, figsize=(15, 5))

# Первая диаграмма
sns.countplot(x='неоплаченные_продукты_штук_квартал', data=seg_1, ax=axes[0])
axes[0].set_title(f'неоплаченные_продукты_штук_квартал - Высокий риск')

# Вторая диаграмма
sns.countplot(x='неоплаченные_продукты_штук_квартал', data=all_other, ax=axes[1])
axes[1].set_title(f'неоплаченные_продукты_штук_квартал - Низкий риск')

# Добавляем заголовок фигуры
fig.suptitle('Распределение неоплаченных_продуктов_штук_квартал')

plt.show()

# Аналогично для среднего_просмотра_категорий_за_визит:

fig, axes = plt.subplots(1, 2, figsize=(15, 5))

# Первая диаграмма
sns.countplot(x='средний_просмотр_категорий_за_визит', data=seg_1, ax=axes[0])
axes[0].set_title(f'средний_просмотр_категорий_за_визит - Высокий риск')

# Вторая диаграмма
sns.countplot(x='средний_просмотр_категорий_за_визит', data=all_other, ax=axes[1])
axes[1].set_title(f'средний_просмотр_категорий_за_визит - Низкий риск')

# Добавляем заголовок фигуры
fig.suptitle('Распределение среднего_просмотра_категорий_за_визит')

plt.show()

# %%
# Аналогично для среднего_просмотра_категорий_за_визит:

fig, axes = plt.subplots(1, 2, figsize=(15, 5))

# Первая диаграмма
sns.boxplot(x='длительность', data=seg_1, ax=axes[0])
axes[0].set_title(f'num__длительность - Высокий риск')

# Вторая диаграмма
sns.boxplot(x='длительность', data=all_other, ax=axes[1])
axes[1].set_title(f'num__длительность - Низкий риск')

# Добавляем заголовок фигуры
fig.suptitle('Распределение num__длительность')

plt.show()

# %%
# Создаем фигуру и оси для диаграмм
fig, axes = plt.subplots(1, 2, figsize=(15, 5))

# Первая диаграмма
sns.countplot(x='текущий_месяц_y', data=seg_1, ax=axes[0])
axes[0].set_title(f'текущий_месяц_y - Высокий риск')

# Вторая диаграмма
sns.countplot(x='текущий_месяц_y', data=all_other, ax=axes[1])
axes[1].set_title(f'текущий_месяц_y - Низкий риск')

# Добавляем заголовок фигуры
fig.suptitle('Распределение num__текущий_месяц_y')

plt.show()

# Аналогично для среднего_просмотра_категорий_за_визит:

fig, axes = plt.subplots(1, 2, figsize=(15, 5))

# Первая диаграмма
sns.countplot(x='предыдущий_месяц_y', data=seg_1, ax=axes[0])
axes[0].set_title(f'num__предыдущий_месяц_y - Высокий риск')

# Вторая диаграмма
sns.countplot(x='предыдущий_месяц_y', data=all_other, ax=axes[1])
axes[1].set_title(f'предыдущий_месяц_y - Низкий риск')

# Добавляем заголовок фигуры
fig.suptitle('Распределение предыдущий_месяц_y')

plt.show()

# %%
# Аналогично для среднего_просмотра_категорий_за_визит:

fig, axes = plt.subplots(1, 2, figsize=(15, 5))

# Первая диаграмма
sns.countplot(x='ошибка_сервиса', data=seg_1, ax=axes[0])
axes[0].set_title(f'num__ошибка_сервиса - Высокий риск')

# Вторая диаграмма
sns.countplot(x='ошибка_сервиса', data=all_other, ax=axes[1])
axes[1].set_title(f'ошибка_сервиса - Низкий риск')

# Добавляем заголовок фигуры
fig.suptitle('Распределение ошибка_сервиса')

plt.show()

# %% [markdown]
# Выводы для Высокого риска оттока:
# - Видим, что у клиентов со снижением активности, очень мало аукционных покупок
# - Снижается количество неоплаченных покупок
# - количество маркетинговых коммуникаций в текущем месяце одинаковое
# - увеличивается средний просмотр категорий за визит
# - длительность рспределяется примерно одинаково. Медиана у людей с риском оттока уменьшается - длительность нахождения на сайте уменьшается
# - num__текущий_месяц_y - количество страниц увеличивается
# - num__предыдущий_месяц_y - количество страниц увеличивается еще больше
# - тип_сервиса - снизилось количество подписок

# %% [markdown]
# ####  8.3 Сделайте выводы о сегментах:
#     - какой сегмент вы взяли для дополнительного исследования,
#     - какие предложения вы сделали и почему.

# %% [markdown]
# Я выбрала сегмент “Высокоприбыльные с низкой вероятностью снижения активности” для дополнительного исследования.- Этот сегмент представляет собой ключевую группу для увеличения прибыли и укрепления лояльности. Эти клиенты уже демонстрируют высокую ценность для бизнеса, но у них есть потенциал для дальнейшего роста. И для сравнения она идеально подходит
#
# Вывод о высокоприбыльные с высокой вероятностью снижения активности:
#
# - Снижение активности в покупках: Клиенты с высоким риском оттока совершают меньше акционных покупок и имеют меньше неоплаченных покупок, что говорит о снижении интереса к продуктам.
# - Повышение активности в просмотре: В то же время, эти клиенты стали больше просматривать категории товаров, возможно, ищут альтернативы или изучают ассортимент.
# - Изменения в поведении на сайте: Средняя длительность пребывания на сайте снижается, но количество просмотренных страниц в текущем и предыдущем месяцах увеличилось, что может свидетельствовать о поиске информации, но не о принятии решения о покупке.
# - Снижение активности в подписках: Наблюдается снижение количества подписок, что может быть признаком снижения удовлетворенности сервисом.
# - Увеличилось количество ошибок на сайте
#
#
# Предложения по работе с сегментом:
#
# 1. Повышение привлекательности ассортимента:
#
# - Акции и скидки: Предложите специальные акции и скидки на продукты, которые чаще покупали клиенты с низким риском оттока.
# - Персонализированные предложения: Используйте историю покупок и просмотров клиентов, чтобы предлагать им релевантные товары и услуги.
# - Новые продукты: Предложите клиентам новинки и эксклюзивные предложения.
#
# 2. Улучшение качества сервиса:
#
# - Обратная связь: Соберите отзывы от клиентов с высоким риском оттока, чтобы узнать, с чем они сталкиваются и как можно улучшить сервис.
# - Устранение проблем: Решите проблемы, которые возникают у клиентов с подписками (например, неудобный интерфейс, неудовлетворительное качество услуг).
#
# 3. Вовлечение клиентов:
#
# - Социальные сети: Активно общайтесь с клиентами в социальных сетях, делитесь интересной информацией о продуктах и услугах, проводите конкурсы и розыгрыши.
# - Контент-маркетинг: Создайте ценный контент, который будет интересен клиентам, например, статьи, видео, подкасты.
# - Лояльность: Введите программу лояльности, которая мотивирует клиентов делать покупки.
# - Большие скидки для преумиум подписок, чтобы клиенты покупали подписки

# %% [markdown]
# ### Общий вывод

# %% [markdown]
# 1. Предобработка данныч
# - в таблице money - выбросов и аномальных значний нет
# - в таблице market_time - выбросов и аномальных значний нет
# - в таблице market_money = удалили выброс 'выручка >= 100000'
# - в таблице market_file - выбросов и аномальных значний нет
#
# 2. иследовательский анализ
#
# - в таблице money - выбросов и аномальных значний нет
# - в таблице market_time - выбросов и аномальных значний нет
# - в таблице market_money = удалили выброс 'выручка >= 100000'
# - в таблице market_file - выбросов и аномальных значний нет
#
# - покупательская активность в боьшистве осталась прежней
# - в основном покупатели придерживаются типа сервиса - стандарт
# - самая популярная категория - Товары для детей
# - чаще всего люди покупают без акций
# 3. Корреляционный анализ
# Мы нашли мультиколлинеарность признаков текущий_месяц_x,предыдущий_месяц_x со многими столбцами и удалили эти признаки из датафрейма
# 4. Пайплайн
#
# Лучшая модель - LogisticRegression(C=3, penalty='l1', random_state=42, solver='liblinear'). Лучший стандартизатор - RobustScaler()
#
# 5. Анализ важности признаков
#
# - **Малозначимые признаки:** разрешить_сообщать, тип_сервиса, предпредыдущий_месяц - эти признаки имеют очень низкое значение важности по перестановке (Permutation Importance). Их влияние на модель минимально, можно рассмотреть возможность их удаления для упрощения модели.
# -  **Важные признаки:**
# - *Сильнее всего влияют на целевой признак:* страниц_за_визит, предыдущий_месяц_y, акционные_покупки.
# - *Также важны:* средний_просмотр_категорий_за_визит, неоплаченные_продукты_штук_квартал, маркет_актив_6_мес, текущий_месяц_y.
# -  **Интерпретация SHAP-значений:**
# -  акционные_покупки и неоплаченные_продукты_штук_квартал: Чем больше значения этих признаков, тем меньше SHAP-значения. Это означает, что чем больше клиент совершает акционных покупок и имеет неоплаченных продуктов, тем выше вероятность, что целевой признак будет равен 0 (например, “Снизилась”).
# -  предыдущий_месяц_y, страниц_за_визит, средний_просмотр_категорий_за_визит: Чем больше значения этих признаков, тем выше SHAP-значения. Это означает, что чем больше “предыдущий месяц_y”, “страниц_за_визит” и “средний просмотр категорий” у клиента, тем выше вероятность, что целевой признак будет равен 1 (например, “Осталась стабильной”).
#
# 6. Сегментация
#
# Я выбрала сегмент “Высокоприбыльные с низкой вероятностью снижения активности” для дополнительного исследования.- Этот сегмент представляет собой ключевую группу для увеличения прибыли и укрепления лояльности. Эти клиенты уже демонстрируют высокую ценность для бизнеса, но у них есть потенциал для дальнейшего роста. И для сравнения она идеально подходит
#
# Вывод о высокоприбыльные с высокой вероятностью снижения активности:
#
# - Снижение активности в покупках: Клиенты с высоким риском оттока совершают меньше акционных покупок и имеют меньше неоплаченных покупок, что говорит о снижении интереса к продуктам.
# - Повышение активности в просмотре: В то же время, эти клиенты стали больше просматривать категории товаров, возможно, ищут альтернативы или изучают ассортимент.
# - Изменения в поведении на сайте: Средняя длительность пребывания на сайте снижается, но количество просмотренных страниц в текущем и предыдущем месяцах увеличилось, что может свидетельствовать о поиске информации, но не о принятии решения о покупке.
# - Снижение активности в подписках: Наблюдается снижение количества подписок, что может быть признаком снижения удовлетворенности сервисом.
# - Увеличилось количество ошибок на сайте
#
#
# Предложения по работе с сегментом:
#
# 1. Повышение привлекательности ассортимента:
#
# - Акции и скидки: Предложите специальные акции и скидки на продукты, которые чаще покупали клиенты с низким риском оттока.
# - Персонализированные предложения: Используйте историю покупок и просмотров клиентов, чтобы предлагать им релевантные товары и услуги.
# - Новые продукты: Предложите клиентам новинки и эксклюзивные предложения.
#
# 2. Улучшение качества сервиса:
#
# - Обратная связь: Соберите отзывы от клиентов с высоким риском оттока, чтобы узнать, с чем они сталкиваются и как можно улучшить сервис.
# - Устранение проблем: Решите проблемы, которые возникают у клиентов с подписками (например, неудобный интерфейс, неудовлетворительное качество услуг).
#
# 3. Вовлечение клиентов:
#
# - Социальные сети: Активно общайтесь с клиентами в социальных сетях, делитесь интересной информацией о продуктах и услугах, проводите конкурсы и розыгрыши.
# - Контент-маркетинг: Создайте ценный контент, который будет интересен клиентам, например, статьи, видео, подкасты.
# - Лояльность: Введите программу лояльности, которая мотивирует клиентов делать покупки.
# - Большие скидки для преумиум подписок, чтобы клиенты покупали подписки
